# %% [markdown]
# # Tutorial - Dynamics Canalization Map (DCM)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
# from cana.boolean_network import BooleanNetwork
import cana
from cana.datasets.bio import BREAST_CANCER
# from cana.datasets.regan_networks import load_all_regan_pi3k_models
from cana.drawing.canalizing_map import draw_canalizing_map_graphviz
from IPython.display import display
import re

# %%
def make_DCM (N, filename='output.png', FLAG_VIEW=True):
    # Request the DCM to the Network
    dcm = N.dynamics_canalization_map(simplify=True)
    # Draws using the graphviz interface.
    gdcm = draw_canalizing_map_graphviz(dcm)
    gdcm.render(filename, view=FLAG_VIEW)
    # Display
    display(gdcm)

# %%
breast_cancer_N = BREAST_CANCER()
# regan_models = []
# regan_models = load_all_regan_pi3k_models()
# N = BooleanNetwork.from_file('/Regan2012Apoptosis.txt',type='logical', keep_constrants=True)
# for N in regan_models:
#     print(N.name)

# %%
# Request the CM for one node (note that the node doesn't know the name of its inputs)
CM = breast_cancer_N.nodes[3].canalizing_map()
# # Draw using the graphviz interface.
gCM = draw_canalizing_map_graphviz(CM)
# # Display
display(gCM)
# Out:
# Warning: node 'var-3-out-0', graph '%3' size too small for label
# Warning: node 'var-3-out-1', graph '%3' size too small for label

# %%
# Make the Albert breast cancer model DCM
# make_DCM(breast_cancer_N, 'Albert_breast_cancer_model_DCM', True)
DCM = breast_cancer_N.dynamics_canalization_map(simplify=True)

# Make the Regan PI3K model DCMs
# for N in regan_models:
#     make_DCM(N, N.name, True)

gDCM = draw_canalizing_map_graphviz(DCM)
# Display
display(DCM)

# %%
reg = re.compile("Ful+")

string = "Fulvestrant-1"
match = bool(re.match(reg, string))
print(match)

for node in DCM.nodes:
    match = bool(re.match(reg, node))
    print(node)
    print(match)
    if match == True:
        print(node)
        print(match)
# Out:
# True
# var-0-out-0
# False
# var-0-out-1
# False
# var-1-out-0
# False
# var-1-out-1
# False
# thr-0-var-1-out-0
# False
# var-2-out-0
# False
# fus-0-thr-0-var-1-out-0
# False
# var-10-out-0
# False
# var-42-out-0
# False
# thr-1-var-1-out-1
# False
# fus-0-thr-1-var-1-out-1
# False
# var-2-out-1
# False
# thr-2-var-1-out-1
# False
# var-10-out-1
# False
# var-42-out-1
# False
# thr-0-var-2-out-0
# False
# fus-0-thr-0-var-2-out-0
# False
# var-50-out-1
# False
# thr-3-var-2-out-1
# False
# var-50-out-0
# False
# thr-4-var-2-out-1
# False
# var-3-out-0
# False
# var-3-out-1
# False
# var-4-out-0
# False
# var-4-out-1
# False
# var-5-out-0
# False
# var-5-out-1
# False
# var-6-out-0
# False
# var-6-out-1
# False
# var-7-out-0
# False
# var-7-out-1
# False
# var-8-out-0
# False
# var-8-out-1
# False
# var-9-out-0
# False
# var-9-out-1
# False
# var-11-out-0
# False
# var-11-out-1
# False
# var-12-out-0
# False
# var-12-out-1
# False
# thr-0-var-12-out-0
# False
# var-13-out-0
# False
# thr-1-var-12-out-1
# False
# fus-0-thr-1-var-12-out-1
# False
# var-13-out-1
# False
# thr-0-var-13-out-0
# False
# fus-0-thr-0-var-13-out-0
# False
# thr-1-var-13-out-1
# False
# var-14-out-0
# False
# var-14-out-1
# False
# var-15-out-0
# False
# thr-2-var-77-out-1
# False
# fus-0-thr-2-var-77-out-0
# False
# fus-0-thr-2-var-77-out-1
# False
# thr-4-var-77-out-1
# False
# var-78-out-0
# False
# var-78-out-1
# False
# thr-0-var-78-out-0
# False
# fus-0-thr-0-var-78-out-0
# False
# thr-1-var-78-out-0
# False
# thr-2-var-78-out-1
# False
# fus-0-thr-2-var-78-out-0
# False
# var-79-out-0
# False
# var-79-out-1
# False
# thr-0-var-79-out-0
# False
# fus-0-thr-0-var-79-out-1
# False
# thr-1-var-79-out-0
# False
# fus-0-thr-1-var-79-out-0
# False
# thr-3-var-79-out-1
# False

# %%
gDCM.render('output.pdf', view=True)
# Display
display(gDCM)

# %%
# Out:
# Warning: node 'var-0-out-0', graph '%3' size too small for label
# Warning: node 'var-0-out-1', graph '%3' size too small for label
# Warning: node 'var-1-out-0', graph '%3' size too small for label
# Warning: node 'var-1-out-1', graph '%3' size too small for label
# Warning: node 'var-2-out-0', graph '%3' size too small for label
# Warning: node 'var-10-out-0', graph '%3' size too small for label
# Warning: node 'var-42-out-0', graph '%3' size too small for label
# Warning: node 'var-2-out-1', graph '%3' size too small for label
# Warning: node 'var-10-out-1', graph '%3' size too small for label
# Warning: node 'var-42-out-1', graph '%3' size too small for label
# Warning: node 'var-3-out-0', graph '%3' size too small for label
# Warning: node 'var-3-out-1', graph '%3' size too small for label
# Warning: node 'var-4-out-0', graph '%3' size too small for label
# Warning: node 'var-4-out-1', graph '%3' size too small for label
# Warning: node 'var-5-out-0', graph '%3' size too small for label
# Warning: node 'var-5-out-1', graph '%3' size too small for label
# Warning: node 'var-6-out-0', graph '%3' size too small for label
# Warning: node 'var-6-out-1', graph '%3' size too small for label
# Warning: node 'var-7-out-0', graph '%3' size too small for label
# Warning: node 'var-7-out-1', graph '%3' size too small for label
# Warning: node 'var-8-out-0', graph '%3' size too small for label
# Warning: node 'var-8-out-1', graph '%3' size too small for label
# Warning: node 'var-9-out-0', graph '%3' size too small for label
# Warning: node 'var-9-out-1', graph '%3' size too small for label
# Warning: node 'var-11-out-0', graph '%3' size too small for label
# Warning: node 'var-11-out-1', graph '%3' size too small for label
# Warning: node 'var-12-out-0', graph '%3' size too small for label
# Warning: node 'var-12-out-1', graph '%3' size too small for label
# Warning: node 'var-13-out-0', graph '%3' size too small for label
# Warning: node 'var-13-out-1', graph '%3' size too small for label
# Warning: node 'var-14-out-0', graph '%3' size too small for label
# Warning: node 'var-14-out-1', graph '%3' size too small for label
# Warning: node 'var-15-out-0', graph '%3' size too small for label
# Warning: node 'var-15-out-1', graph '%3' size too small for label
# Warning: node 'var-16-out-0', graph '%3' size too small for label
# Warning: node 'var-16-out-1', graph '%3' size too small for label
# Warning: node 'var-17-out-0', graph '%3' size too small for label
# Warning: node 'var-17-out-1', graph '%3' size too small for label
# Warning: node 'var-19-out-0', graph '%3' size too small for label
# Warning: node 'var-19-out-1', graph '%3' size too small for label
# Warning: node 'var-20-out-0', graph '%3' size too small for label
# Warning: node 'var-20-out-1', graph '%3' size too small for label
# Warning: node 'var-25-out-1', graph '%3' size too small for label
# Warning: node 'var-25-out-0', graph '%3' size too small for label
# Warning: node 'var-22-out-0', graph '%3' size too small for label
# Warning: node 'var-23-out-0', graph '%3' size too small for label
# Warning: node 'var-22-out-1', graph '%3' size too small for label
# Warning: node 'var-23-out-1', graph '%3' size too small for label
# Warning: node 'var-24-out-0', graph '%3' size too small for label
# Warning: node 'var-24-out-1', graph '%3' size too small for label
# Warning: node 'var-30-out-0', graph '%3' size too small for label
# Warning: node 'var-30-out-1', graph '%3' size too small for label
# Warning: node 'var-27-out-0', graph '%3' size too small for label
# Warning: node 'var-27-out-1', graph '%3' size too small for label
# Warning: node 'var-28-out-0', graph '%3' size too small for label
# Warning: node 'var-28-out-1', graph '%3' size too small for label
# Warning: node 'var-31-out-0', graph '%3' size too small for label
# Warning: node 'var-31-out-1', graph '%3' size too small for label
# Warning: node 'var-32-out-0', graph '%3' size too small for label
# Warning: node 'var-32-out-1', graph '%3' size too small for label
# Warning: node 'var-34-out-0', graph '%3' size too small for label
# Warning: node 'var-34-out-1', graph '%3' size too small for label
# Warning: node 'var-60-out-1', graph '%3' size too small for label
# Warning: node 'var-60-out-0', graph '%3' size too small for label
# Warning: node 'var-35-out-0', graph '%3' size too small for label
# Warning: node 'var-35-out-1', graph '%3' size too small for label
# Warning: node 'var-36-out-0', graph '%3' size too small for label
# Warning: node 'var-36-out-1', graph '%3' size too small for label
# Warning: node 'var-71-out-0', graph '%3' size too small for label
# Warning: node 'var-72-out-0', graph '%3' size too small for label
# Warning: node 'var-71-out-1', graph '%3' size too small for label
# Warning: node 'var-72-out-1', graph '%3' size too small for label
# Warning: node 'var-37-out-0', graph '%3' size too small for label
# Warning: node 'var-37-out-1', graph '%3' size too small for label
# Warning: node 'var-38-out-0', graph '%3' size too small for label
# Warning: node 'var-38-out-1', graph '%3' size too small for label
# Warning: node 'var-40-out-0', graph '%3' size too small for label
# Warning: node 'var-40-out-1', graph '%3' size too small for label
# Warning: node 'var-41-out-0', graph '%3' size too small for label
# Warning: node 'var-41-out-1', graph '%3' size too small for label
# Warning: node 'var-43-out-1', graph '%3' size too small for label
# Warning: node 'var-43-out-0', graph '%3' size too small for label
# Warning: node 'var-44-out-0', graph '%3' size too small for label
# Warning: node 'var-44-out-1', graph '%3' size too small for label
# Warning: node 'var-45-out-0', graph '%3' size too small for label
# Warning: node 'var-45-out-1', graph '%3' size too small for label
# Warning: node 'var-48-out-0', graph '%3' size too small for label
# Warning: node 'var-48-out-1', graph '%3' size too small for label
# Warning: node 'var-51-out-0', graph '%3' size too small for label
# Warning: node 'var-51-out-1', graph '%3' size too small for label
# Warning: node 'var-49-out-0', graph '%3' size too small for label
# Warning: node 'var-49-out-1', graph '%3' size too small for label
# Warning: node 'var-53-out-0', graph '%3' size too small for label
# Warning: node 'var-53-out-1', graph '%3' size too small for label
# Warning: node 'var-54-out-0', graph '%3' size too small for label
# Warning: node 'var-54-out-1', graph '%3' size too small for label
# Warning: node 'var-55-out-0', graph '%3' size too small for label
# Warning: node 'var-55-out-1', graph '%3' size too small for label
# Warning: node 'var-56-out-0', graph '%3' size too small for label
# Warning: node 'var-56-out-1', graph '%3' size too small for label
# Warning: node 'var-57-out-0', graph '%3' size too small for label
# Warning: node 'var-57-out-1', graph '%3' size too small for label
# Warning: node 'var-58-out-0', graph '%3' size too small for label
# Warning: node 'var-58-out-1', graph '%3' size too small for label
# Warning: node 'var-61-out-0', graph '%3' size too small for label
# Warning: node 'var-61-out-1', graph '%3' size too small for label
# Warning: node 'var-62-out-0', graph '%3' size too small for label
# Warning: node 'var-62-out-1', graph '%3' size too small for label
# Warning: node 'var-63-out-0', graph '%3' size too small for label
# Warning: node 'var-63-out-1', graph '%3' size too small for label
# Warning: node 'var-64-out-0', graph '%3' size too small for label
# Warning: node 'var-64-out-1', graph '%3' size too small for label
# Warning: node 'var-65-out-0', graph '%3' size too small for label
# Warning: node 'var-65-out-1', graph '%3' size too small for label
# Warning: node 'var-66-out-0', graph '%3' size too small for label
# Warning: node 'var-66-out-1', graph '%3' size too small for label
# Warning: node 'var-68-out-0', graph '%3' size too small for label
# Warning: node 'var-69-out-0', graph '%3' size too small for label
# Warning: node 'var-68-out-1', graph '%3' size too small for label
# Warning: node 'var-69-out-1', graph '%3' size too small for label
# Warning: node 'var-73-out-0', graph '%3' size too small for label
# Warning: node 'var-73-out-1', graph '%3' size too small for label
# Warning: node 'var-74-out-0', graph '%3' size too small for label
# Warning: node 'var-74-out-1', graph '%3' size too small for label
# Warning: node 'var-75-out-0', graph '%3' size too small for label
# Warning: node 'var-75-out-1', graph '%3' size too small for label
# Warning: node 'var-76-out-0', graph '%3' size too small for label
# Warning: node 'var-76-out-1', graph '%3' size too small for label
# Warning: node 'var-77-out-0', graph '%3' size too small for label
# Warning: node 'var-77-out-1', graph '%3' size too small for label
# Warning: node 'var-78-out-0', graph '%3' size too small for label
# Warning: node 'var-78-out-1', graph '%3' size too small for label
# Warning: node 'var-79-out-0', graph '%3' size too small for label
# Warning: node 'var-79-out-1', graph '%3' size too small for label
# Warning: node 'var-0-out-0', graph '%3' size too small for label
# Warning: node 'var-0-out-1', graph '%3' size too small for label
# Warning: node 'var-1-out-0', graph '%3' size too small for label
# Warning: node 'var-1-out-1', graph '%3' size too small for label
# Warning: node 'var-2-out-0', graph '%3' size too small for label
# Warning: node 'var-10-out-0', graph '%3' size too small for label
# Warning: node 'var-42-out-0', graph '%3' size too small for label
# Warning: node 'var-2-out-1', graph '%3' size too small for label
# Warning: node 'var-10-out-1', graph '%3' size too small for label
# Warning: node 'var-42-out-1', graph '%3' size too small for label
# Warning: node 'var-3-out-0', graph '%3' size too small for label
# Warning: node 'var-3-out-1', graph '%3' size too small for label
# Warning: node 'var-4-out-0', graph '%3' size too small for label
# Warning: node 'var-4-out-1', graph '%3' size too small for label
# Warning: node 'var-5-out-0', graph '%3' size too small for label
# Warning: node 'var-5-out-1', graph '%3' size too small for label
# Warning: node 'var-6-out-0', graph '%3' size too small for label
# Warning: node 'var-6-out-1', graph '%3' size too small for label
# Warning: node 'var-7-out-0', graph '%3' size too small for label
# Warning: node 'var-7-out-1', graph '%3' size too small for label
# Warning: node 'var-8-out-0', graph '%3' size too small for label
# Warning: node 'var-8-out-1', graph '%3' size too small for label
# Warning: node 'var-9-out-0', graph '%3' size too small for label
# Warning: node 'var-9-out-1', graph '%3' size too small for label
# Warning: node 'var-11-out-0', graph '%3' size too small for label
# Warning: node 'var-11-out-1', graph '%3' size too small for label
# Warning: node 'var-12-out-0', graph '%3' size too small for label
# Warning: node 'var-12-out-1', graph '%3' size too small for label
# Warning: node 'var-13-out-0', graph '%3' size too small for label
# Warning: node 'var-13-out-1', graph '%3' size too small for label
# Warning: node 'var-14-out-0', graph '%3' size too small for label
# Warning: node 'var-14-out-1', graph '%3' size too small for label
# Warning: node 'var-15-out-0', graph '%3' size too small for label
# Warning: node 'var-15-out-1', graph '%3' size too small for label
# Warning: node 'var-16-out-0', graph '%3' size too small for label
# Warning: node 'var-16-out-1', graph '%3' size too small for label
# Warning: node 'var-17-out-0', graph '%3' size too small for label
# Warning: node 'var-17-out-1', graph '%3' size too small for label
# Warning: node 'var-19-out-0', graph '%3' size too small for label
# Warning: node 'var-19-out-1', graph '%3' size too small for label
# Warning: node 'var-20-out-0', graph '%3' size too small for label
# Warning: node 'var-20-out-1', graph '%3' size too small for label
# Warning: node 'var-25-out-1', graph '%3' size too small for label
# Warning: node 'var-25-out-0', graph '%3' size too small for label
# Warning: node 'var-22-out-0', graph '%3' size too small for label
# Warning: node 'var-23-out-0', graph '%3' size too small for label
# Warning: node 'var-22-out-1', graph '%3' size too small for label
# Warning: node 'var-23-out-1', graph '%3' size too small for label
# Warning: node 'var-24-out-0', graph '%3' size too small for label
# Warning: node 'var-24-out-1', graph '%3' size too small for label
# Warning: node 'var-30-out-0', graph '%3' size too small for label
# Warning: node 'var-30-out-1', graph '%3' size too small for label
# Warning: node 'var-27-out-0', graph '%3' size too small for label
# Warning: node 'var-27-out-1', graph '%3' size too small for label
# Warning: node 'var-28-out-0', graph '%3' size too small for label
# Warning: node 'var-28-out-1', graph '%3' size too small for label
# Warning: node 'var-31-out-0', graph '%3' size too small for label
# Warning: node 'var-31-out-1', graph '%3' size too small for label
# Warning: node 'var-32-out-0', graph '%3' size too small for label
# Warning: node 'var-32-out-1', graph '%3' size too small for label
# Warning: node 'var-34-out-0', graph '%3' size too small for label
# Warning: node 'var-34-out-1', graph '%3' size too small for label
# Warning: node 'var-60-out-1', graph '%3' size too small for label
# Warning: node 'var-60-out-0', graph '%3' size too small for label
# Warning: node 'var-35-out-0', graph '%3' size too small for label
# Warning: node 'var-35-out-1', graph '%3' size too small for label
# Warning: node 'var-36-out-0', graph '%3' size too small for label
# Warning: node 'var-36-out-1', graph '%3' size too small for label
# Warning: node 'var-71-out-0', graph '%3' size too small for label
# Warning: node 'var-72-out-0', graph '%3' size too small for label
# Warning: node 'var-71-out-1', graph '%3' size too small for label
# Warning: node 'var-72-out-1', graph '%3' size too small for label
# Warning: node 'var-37-out-0', graph '%3' size too small for label
# Warning: node 'var-37-out-1', graph '%3' size too small for label
# Warning: node 'var-38-out-0', graph '%3' size too small for label
# Warning: node 'var-38-out-1', graph '%3' size too small for label
# Warning: node 'var-40-out-0', graph '%3' size too small for label
# Warning: node 'var-40-out-1', graph '%3' size too small for label
# Warning: node 'var-41-out-0', graph '%3' size too small for label
# Warning: node 'var-41-out-1', graph '%3' size too small for label
# Warning: node 'var-43-out-1', graph '%3' size too small for label
# Warning: node 'var-43-out-0', graph '%3' size too small for label
# Warning: node 'var-44-out-0', graph '%3' size too small for label
# Warning: node 'var-44-out-1', graph '%3' size too small for label
# Warning: node 'var-45-out-0', graph '%3' size too small for label
# Warning: node 'var-45-out-1', graph '%3' size too small for label
# Warning: node 'var-48-out-0', graph '%3' size too small for label
# Warning: node 'var-48-out-1', graph '%3' size too small for label
# Warning: node 'var-51-out-0', graph '%3' size too small for label
# Warning: node 'var-51-out-1', graph '%3' size too small for label
# Warning: node 'var-49-out-0', graph '%3' size too small for label
# Warning: node 'var-49-out-1', graph '%3' size too small for label
# Warning: node 'var-53-out-0', graph '%3' size too small for label
# Warning: node 'var-53-out-1', graph '%3' size too small for label
# Warning: node 'var-54-out-0', graph '%3' size too small for label
# Warning: node 'var-54-out-1', graph '%3' size too small for label
# Warning: node 'var-55-out-0', graph '%3' size too small for label
# Warning: node 'var-55-out-1', graph '%3' size too small for label
# Warning: node 'var-56-out-0', graph '%3' size too small for label
# Warning: node 'var-56-out-1', graph '%3' size too small for label
# Warning: node 'var-57-out-0', graph '%3' size too small for label
# Warning: node 'var-57-out-1', graph '%3' size too small for label
# Warning: node 'var-58-out-0', graph '%3' size too small for label
# Warning: node 'var-58-out-1', graph '%3' size too small for label
# Warning: node 'var-61-out-0', graph '%3' size too small for label
# Warning: node 'var-61-out-1', graph '%3' size too small for label
# Warning: node 'var-62-out-0', graph '%3' size too small for label
# Warning: node 'var-62-out-1', graph '%3' size too small for label
# Warning: node 'var-63-out-0', graph '%3' size too small for label
# Warning: node 'var-63-out-1', graph '%3' size too small for label
# Warning: node 'var-64-out-0', graph '%3' size too small for label
# Warning: node 'var-64-out-1', graph '%3' size too small for label
# Warning: node 'var-65-out-0', graph '%3' size too small for label
# Warning: node 'var-65-out-1', graph '%3' size too small for label
# Warning: node 'var-66-out-0', graph '%3' size too small for label
# Warning: node 'var-66-out-1', graph '%3' size too small for label
# Warning: node 'var-68-out-0', graph '%3' size too small for label
# Warning: node 'var-69-out-0', graph '%3' size too small for label
# Warning: node 'var-68-out-1', graph '%3' size too small for label
# Warning: node 'var-69-out-1', graph '%3' size too small for label
# Warning: node 'var-73-out-0', graph '%3' size too small for label
# Warning: node 'var-73-out-1', graph '%3' size too small for label
# Warning: node 'var-74-out-0', graph '%3' size too small for label
# Warning: node 'var-74-out-1', graph '%3' size too small for label
# Warning: node 'var-75-out-0', graph '%3' size too small for label
# Warning: node 'var-75-out-1', graph '%3' size too small for label
# Warning: node 'var-76-out-0', graph '%3' size too small for label
# Warning: node 'var-76-out-1', graph '%3' size too small for label
# Warning: node 'var-77-out-0', graph '%3' size too small for label
# Warning: node 'var-77-out-1', graph '%3' size too small for label
# Warning: node 'var-78-out-0', graph '%3' size too small for label
# Warning: node 'var-78-out-1', graph '%3' size too small for label
# Warning: node 'var-79-out-0', graph '%3' size too small for label
# Warning: node 'var-79-out-1', graph '%3' size too small for label
